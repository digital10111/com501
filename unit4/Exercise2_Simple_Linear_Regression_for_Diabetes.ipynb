# %% [markdown]
# # Apply Linear Regression Model on Diabetes
#
# **Learning Outcomes**
#
# 1. Attempt to apply linear regression on an unsuitable dataset
# 2. Understand the difference between the model limitation and the inherited data limitations
#
#
# In this exercise you create a linear regression model that will allow us to predict the level of diabetes a person have.
# Bear in mind however, that this data is more suitable for a classification model. In the next unit we will see how to use linear models to classify a dataset via a perceptron. For now, you will be able to appreciate that the data is hard to be used to predict precisely the diabetes level. Even if we employ a non-linear model, the data is not amenable as can be seen from the visualisation.

# %%
# disclaimer the fowlloing is an amended version of sklearn exercise

import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Load the diabetes dataset
X, y = datasets.load_diabetes(return_X_y=True)

# %%
# disclaimer the fowlloing is an amended version of sklearn exercise

import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Load the diabetes dataset
X, y = datasets.load_diabetes(return_X_y=True)

# Use only one feature
X = X[:, np.newaxis, 2]

# Split the data into training/testing sets
X_train = X[:-20]
X_test = X[-20:]

# Split the targets into training/testing sets
y_train = y[:-20]
y_test = y[-20:]

regr = linear_model.LinearRegression()     # Create linear regression object
regr.fit(X_train, y_train)                 # Train the model using the training sets
y_pred = regr.predict(X_test)              # Make predictions using the testing set


print('Coefficients: \n', regr.coef_)
print('Mean squared error: %.2f'           % mean_squared_error(y_test, y_pred))
print('Coefficient of determination: %.2f' % r2_score(y_test, y_pred))   #1 is perfect prediction

# Plot outputs
plt.xticks(())
plt.yticks(())
plt.scatter(X_test, y_test, color='black')
plt.plot   (X_test, y_pred, color='blue', linewidth=3)
plt.savefig('figures\linearRegression.png')
# Out:
# Coefficients:
#  [938.23786125]
# Mean squared error: 2548.07
# Coefficient of determination: 0.47

# %% [markdown]
# As can be seen, the model does not seem to fit the data well. However, even if we employ a more complex model the data is simply more suitable for classification not regression. To see why let us visualise the training data (which is what we should have done from the start :)

# %%
plt.scatter(X_train, y_train, color='black')
plt.plot   (X_train, regr.predict(X_train), color='blue', linewidth=3)
