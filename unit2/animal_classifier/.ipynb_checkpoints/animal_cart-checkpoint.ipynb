# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("animal_class_dataset.tsv", sep="\t")

# %%
df
# Out:
#              name  gives_birth  warm-blooded  aquatic_creature  \
# 0           human            1             1                 0
# 1          python            0             0                 0
# 2          salmon            0             0                 1
# 3           whale            1             1                 1
# 4            frog            0             0                 1
# 5          komodo            0             0                 0
# 6             bat            1             1                 0
# 7          pigeon            0             1                 0
# 8             cat            1             1                 0
# 9   leopard shark            1             0                 1
# 10         turtle            0             0                 1
# 11        penguin            0             1                 1
# 12      porcupine            1             1                 0
# 13            eel            0             0                 1
# 14     salamander            0             0                 1
#
#     aerial_creature  has_legs  hibernates animal_class
# 0                 0         1           0      mammals
# 1                 0         0           1     reptiles
# 2                 0         0           0         fish
# 3                 0         0           0      mammals
# 4                 0         1           1   amphibians
# 5                 0         1           0     reptiles
# 6                 1         1           1      mammals
# 7                 1         1           0        birds
# 8                 0         1           0      mammals
# 9                 0         0           0         fish
# 10                0         1           0     reptiles
# 11                0         1           0        birds
# 12                0         1           1      mammals
# 13                0         0           0         fish
# 14                0         1           1   amphibians

# %%
featuers = list(set(df.columns) - {"name", "animal_class"})

# %%
featuers
# Out:
# ['aerial_creature',
#  'aquatic_creature',
#  'warm-blooded',
#  'hibernates',
#  'has_legs',
#  'gives_birth']

# %%
for featuer in featuers:
