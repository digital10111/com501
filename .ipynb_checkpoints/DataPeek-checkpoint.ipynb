# %%
import pandas as pd
from matplotlib import pyplot
import seaborn as sns
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("creditcard_dataset_2022.csv")

# %%
df.head()
# Out:
#          V1         V2         V3         V4         V5        V6         V7  \
# 0       NaN   3.854150 -12.466766   9.648311  -2.726961 -4.445610 -21.922811
# 1       NaN  -1.093377  -0.059768   1.064785  11.095089 -5.430971  -9.378025
# 2       NaN   1.861373  -4.310353   2.448080   4.574094 -2.979912  -2.792379
# 3       NaN  11.614801 -19.739386  10.463866 -12.599146 -1.202393 -23.380508
# 4 -0.451383   2.225147  -4.953050   4.342228  -3.656190 -0.020121  -5.407554
#
#          V8        V9        V10  ...       V22     V22.1        V23  \
# 0  0.320792 -4.433162 -11.201400  ... -1.504119 -1.504119 -19.254328
# 1 -0.446456  1.992110   1.785922  ... -1.259697 -1.259697 -15.981649
# 2 -2.719867 -0.276704  -2.314747  ... -0.348904 -0.348904  -3.979948
# 3 -5.781133 -7.811022 -16.303538  ...  1.140910  1.140910   1.392953
# 4 -0.748436 -1.362198  -4.170623  ...  0.495889  0.495889   1.154128
#
#         V24       V25       V26       V27       V28   Amount  Normal
# ...

# %%
df.dtypes.value_counts()
# Out:
# float64    30
# int64       1
# dtype: int64

# %%
df.shape
# Out:
# (9999, 31)

# %%
print(df.Normal.value_counts(normalize=True).mul(100))
print(df.Normal.value_counts(normalize=False))
# Out:
# 1    95.059506
# 0     4.940494
# Name: Normal, dtype: float64
# 1    9505
# 0     494
# Name: Normal, dtype: int64

# %%
df.isnull().sum()
# Out:
# V1        7
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V22.1     0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Normal    0
# dtype: int64

# %%
features = [col for col in df.columns if 'V' in col]
features.append("Amount")
features = np.asarray(features)
features = features.reshape(6, 5).tolist()

# %%
fig, axs = pyplot.subplots(6, 5, figsize=(30, 20))

for i, feature_row in enumerate(features):
    for j, feature in enumerate(feature_row):
        sns.kdeplot(df[feature], hue=df.Normal, ax=axs[i][j])

fig.tight_layout()

# %%
fig, ax = pyplot.subplots(figsize=(15, 10))
sns.heatmap(df.corr(), cmap="coolwarm", ax=ax)
# Out:
# <AxesSubplot:>

# %%
df.V1.fillna(df.V1.mean(), inplace=True)
cs = cosine_similarity(df.drop(["Amount", "Normal"], axis=1))

# %%
sns.kdeplot(cs[0])
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
top_fraud_type_distinguishers = set(["V1", "V2", "V3", "V5", "V7", "V9", "V10", "V12", "V16", "V17", "V18"])
good_fraud_type_distinguishers = set([""])
